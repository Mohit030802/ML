# %% [markdown]
# # 1 My first ML Model

# %%
# getting started
import pandas as pd
df=pd.read_csv('vgsales.csv')
df.shape
# Out:
# (16598, 11)

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %% [markdown]
# ## First Real World Problem
# ### Music suggestion data

# %%
#importing the data

import pandas as pd
df=pd.read_csv("music.csv")
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
# cleaning the data

#no need for this dataset as there in no null value

# %%
#taking the input set or feature vector
X=df.drop(columns=['genre'])
y=df['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
model=DecisionTreeClassifier()
# model.fit(X_train,y_train)
model.fit(X,y)
predictions=model.predict(X_test)
score=accuracy_score(y_test,predictions)
# joblib.dump(model,'FirstModel-music-recommender.joblib')
# joblib.load('FirstModel-music-recommender.joblib')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[104], line 4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.metrics import accuracy_score
# ----> 4 from sklearn.externals import joblib
#       5 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
#       6 model=DecisionTreeClassifier()
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\externals\__init__.py)

# %%
from sklearn import tree

tree.export_graphviz(model,out_file=('music-recommender.dot'),
                    feature_names=['age','gender'],
                    class_names=sorted(y.unique()),
                     label='all',
                     rounded=True,
                     filled=True
                    )
